# %%
import os
from typing import TypedDict, List, Union
from dotenv import load_dotenv

from langchain_core.messages import HumanMessage, AIMessage
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_anthropic import ChatAnthropic

from langgraph.graph import StateGraph, START, END

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
gpt_model = ChatOpenAI(
    model="gpt-4o-mini",
    # stream_usage=True,
    # temperature=None,
    # max_tokens=None,
    # timeout=None,
    # reasoning_effort="low",
    # max_retries=2,
    # api_key="...",  # If you prefer to pass api key in directly
    # base_url="...",
    # organization="...",
    # other params...
)

# %%
gemini_model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

# %%
claude_model = ChatAnthropic(
    model="claude-haiku-4-5",
    temperature=0.0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to Chinese. Translate the user sentence.",
    ),
    ("human", "I love playing with large language models."),
]

# %%
gpt_response = gpt_model.invoke(messages)
gpt_response
# Out:
# AIMessage(content='我喜欢和大型语言模型玩耍。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 35, 'total_tokens': 45, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_50906f2aac', 'id': 'chatcmpl-CkynI1v9Xxg9u0Awyu8HyGpy8lzkV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b04d7-e120-7503-a208-91df5681d89e-0', usage_metadata={'input_tokens': 35, 'output_tokens': 10, 'total_tokens': 45, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
gemini_response = gemini_model.invoke(messages)
gemini_response
# Out:
# AIMessage(content='我喜欢玩大型语言模型。', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b04d7-e7f3-7480-89de-69d5b2abfe61-0', usage_metadata={'input_tokens': 25, 'output_tokens': 287, 'total_tokens': 312, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 280}})

# %%
claude_response = claude_model.invoke(messages)
claude_response
# Out:
# AIMessage(content='我喜欢使用大型语言模型。\n\n(Or alternatively: 我喜欢和大型语言模型互动。)', additional_kwargs={}, response_metadata={'id': 'msg_01MUgsBrUZbnn6g8ezKh6zb5', 'model': 'claude-haiku-4-5-20251001', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 33, 'output_tokens': 40, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-haiku-4-5-20251001', 'model_provider': 'anthropic'}, id='lc_run--019b04d7-f39b-7042-a7f7-c6ea88f21270-0', usage_metadata={'input_tokens': 33, 'output_tokens': 40, 'total_tokens': 73, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})
