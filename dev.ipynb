# %%
import os
from typing import TypedDict, List, Union
from dotenv import load_dotenv
from langchain_core.messages import HumanMessage, AIMessage
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_anthropic import ChatAnthropic
from langgraph.graph import StateGraph, START, END

load_dotenv()
# Out:
# True

# %%
class AgentState(TypedDict):
    messages: List[Union[HumanMessage, AIMessage]]

# %%
provider = input("Enter LLM provider (openai/google/anthropic): ").strip().lower()
if provider == "openai":
    llm = ChatOpenAI(model="gpt-4o-mini", 
                     temperature=0.0, 
                     max_tokens=None,
                     timeout=None,
                     max_retries=2)
elif provider == "google":
    llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash",
                                 temperature=0.0,
                                 max_tokens=None,
                                 timeout=None,
                                 max_retries=2)
elif provider == "anthropic":
    llm = ChatAnthropic(model="claude-haiku-4-5",
                        temperature=0.0,
                        max_tokens=None,
                        timeout=None,
                        max_retries=2)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to Chinese. Translate the user sentence.",
    ),
    ("human", "I love playing with large language models."),
]

# %%
response = llm.invoke(messages)
response
# Out:
# AIMessage(content='我喜欢玩大型语言模型。', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b1e8d-3355-7c10-91d6-51c78240a243-0', usage_metadata={'input_tokens': 25, 'output_tokens': 7, 'total_tokens': 32, 'input_token_details': {'cache_read': 0}})

# %%
from pprint import pprint

state = AgentState({'messages': [HumanMessage(content='hi, i am xavi, living at madrid', additional_kwargs={}, response_metadata={}), 
                                 AIMessage(content="# Hi Xavi! �\n\nNice to meet you! Madrid is a great city. I'm Claude, an AI assistant made by Anthropic.\n\nI s there anything I can help you with today? Whether it's questions about Madrid, learning something new, creative projects, problem-solving, or just having a conversation—I'm here to help!", additional_kwargs={}, response_metadata={}), 
                                 HumanMessage(content='who are you', additional_kwargs={}, response_metadata={}), 
                                 AIMessage(content="# I'm Claude, an AI assistant made by Anthropic.\n\nHere's what you should know about me:\n\n**What I am:**\n- An AI trained to be helpful, harmless, and honest\n- A conversational assistant who can help with a wide range of tasks\n- Available 24/7 to chat, answer questions, help with writing, coding, analysis, brainstorming, and much more\n\n**What I can do:**\n- Answer questions on many topics\n- Help with writing, editing, and creative projects\n- Assist with coding and technical problems\n- Explain complex concepts\n- Have thoughtful conversations\n- Help with research and analysis\n\n**What I'm not:**\n- A real person (I'm an AI)\n- Connected to the internet (I can't browse or access real-time information)\n- Able to remember previous conversations (each chat starts fresh)\n- Perfect (I can make mistakes)\n\nIs there something specific you'd like to know about me, or something I can help you with?", additional_kwargs={}, response_metadata={})]})

pprint(state)
# Out:
# {'messages': [HumanMessage(content='hi, i am xavi, living at madrid', additional_kwargs={}, response_metadata={}),
#               AIMessage(content="# Hi Xavi! �\n\nNice to meet you! Madrid is a great city. I'm Claude, an AI assistant made by Anthropic.\n\nI s there anything I can help you with today? Whether it's questions about Madrid, learning something new, creative projects, problem-solving, or just having a conversation—I'm here to help!", additional_kwargs={}, response_metadata={}),
#               HumanMessage(content='who are you', additional_kwargs={}, response_metadata={}),
# ...
